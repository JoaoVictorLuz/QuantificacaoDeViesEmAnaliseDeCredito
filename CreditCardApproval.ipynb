# %% [markdown]
# # Importações e Instalações de Biblioteca

# %%
# !pip install 'aif360[Reductions,inFairness]'
# !pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://packagecloud.io/github/git-lfs/pypi/simple
# Requirement already satisfied: aif360[Reductions,inFairness] in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: numpy>=1.16 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from aif360[Reductions,inFairness]) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from aif360[Reductions,inFairness]) (1.13.0)
# Requirement already satisfied: pandas>=0.24.0 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from aif360[Reductions,inFairness]) (2.2.1)
# Requirement already satisfied: scikit-learn>=1.0 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from aif360[Reductions,inFairness]) (1.4.1.post1)
# Requirement already satisfied: matplotlib in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from aif360[Reductions,inFairness]) (3.8.4)
# Requirement already satisfied: fairlearn~=0.7 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from aif360[Reductions,inFairness]) (0.10.0)
# Requirement already satisfied: skorch in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from aif360[Reductions,inFairness]) (0.15.0)
# Requirement already satisfied: inFairness>=0.2.2 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from aif360[Reductions,inFairness]) (0.2.3)
# Requirement already satisfied: POT>=0.8.0 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from inFairness>=0.2.2->aif360[Reductions,inFairness]) (0.9.3)
# Requirement already satisfied: torch>=1.13.0 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from inFairness>=0.2.2->aif360[Reductions,inFairness]) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from pandas>=0.24.0->aif360[Reductions,inFairness]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from pandas>=0.24.0->aif360[Reductions,inFairness]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from pandas>=0.24.0->aif360[Reductions,inFairness]) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from scikit-learn>=1.0->aif360[Reductions,inFairness]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from scikit-learn>=1.0->aif360[Reductions,inFairness]) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from matplotlib->aif360[Reductions,inFairness]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from matplotlib->aif360[Reductions,inFairness]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from matplotlib->aif360[Reductions,inFairness]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from matplotlib->aif360[Reductions,inFairness]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from matplotlib->aif360[Reductions,inFairness]) (23.2)
# Requirement already satisfied: pillow>=8 in /home/tuao/.local/lib/python3.11/site-packages (from matplotlib->aif360[Reductions,inFairness]) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from matplotlib->aif360[Reductions,inFairness]) (3.1.2)
# Requirement already satisfied: tabulate>=0.7.7 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from skorch->aif360[Reductions,inFairness]) (0.9.0)
# Requirement already satisfied: tqdm>=4.14.0 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from skorch->aif360[Reductions,inFairness]) (4.66.2)
# Requirement already satisfied: six>=1.5 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->aif360[Reductions,inFairness]) (1.16.0)
# Requirement already satisfied: filelock in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (4.11.0)
# Requirement already satisfied: sympy in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (1.12)
# Requirement already satisfied: networkx in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (3.3)
# Requirement already satisfied: jinja2 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (3.1.3)
# Requirement already satisfied: fsspec in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from jinja2->torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (from sympy->torch>=1.13.0->inFairness>=0.2.2->aif360[Reductions,inFairness]) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://packagecloud.io/github/git-lfs/pypi/simple
# Requirement already satisfied: xlrd in /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages (2.0.1)

# %%
from BibliotecasEFuncoes import *
# Out:
# 2024-05-08 19:32:19.339615: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-08 19:32:22.580689: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages/torch/_functorch/deprecated.py:61: UserWarning: We've integrated functorch into PyTorch. As the final step of the integration, functorch.vmap is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use torch.vmap instead; see the PyTorch 2.0 release notes and/or the torch.func migration guide for more details https://pytorch.org/docs/master/func.migrating.html
#   warn_deprecated('vmap', 'torch.vmap')

# %% [markdown]
# # Lendo e processando a base de dados

# %% [markdown]
# Descrição Dos Dados no link: https://www.kaggle.com/datasets/rikdifos/credit-card-approval-prediction/data
# e: https://github.com/semasuka/Credit-card-approval-prediction-classification/tree/main

# %%
# Is high risk : 0=baixo risco na aprovação do crédito , 1=alto risco na aprovação do crédito
base = 'CreditCardApproval'
CreditCard = pd.read_csv('Datasets/CreditCardApproval.csv')
CreditCard.head()
# Out:
#         ID Gender Has a car Has a property  Children count    Income     Employment status                Education level  Marital status             Dwelling    Age  Employment length  Has a mobile phone  Has a work phone  Has a phone  Has an email       Job title  Family member count  Account age  Is high risk
# 0  5091261      F         N              Y               0  202500.0         State servant  Secondary / secondary special       Separated    House / apartment -16834              -1692                   1                 0            0             0  Medicine staff                  1.0         -6.0             0
# 1  5096963      M         Y              N               0  675000.0  Commercial associate               Higher education         Married    House / apartment -18126               -948                   1                 0            1             0        Managers                  2.0        -16.0             0
# 2  5087880      F         N              N               0  234000.0         State servant               Higher education  Civil marriage    House / apartment -21967              -5215                   1                 0            0             1      Core staff                  2.0        -52.0             0
# 3  5021949      F         Y              Y               0  445500.0  Commercial associate               Higher education         Married    House / apartment -12477               -456                   1                 0            0             0        Managers                  2.0        -54.0             0
# 4  5105705      F         Y              N               0  225000.0               Working  Secondary / secondary special         Married  Municipal apartment -12155               -667                   1                 0            0             0        Laborers                  2.0        -48.0             0

# %%
CreditCard.rename(columns={'Is high risk' : 'class'}, inplace=True)

#separando rótulo (variável dependente y)
df_y = CreditCard['class']

# %%
CreditCard.head()
# Out:
#         ID Gender Has a car Has a property  Children count    Income     Employment status                Education level  Marital status             Dwelling    Age  Employment length  Has a mobile phone  Has a work phone  Has a phone  Has an email       Job title  Family member count  Account age  class
# 0  5091261      F         N              Y               0  202500.0         State servant  Secondary / secondary special       Separated    House / apartment -16834              -1692                   1                 0            0             0  Medicine staff                  1.0         -6.0      0
# 1  5096963      M         Y              N               0  675000.0  Commercial associate               Higher education         Married    House / apartment -18126               -948                   1                 0            1             0        Managers                  2.0        -16.0      0
# 2  5087880      F         N              N               0  234000.0         State servant               Higher education  Civil marriage    House / apartment -21967              -5215                   1                 0            0             1      Core staff                  2.0        -52.0      0
# 3  5021949      F         Y              Y               0  445500.0  Commercial associate               Higher education         Married    House / apartment -12477               -456                   1                 0            0             0        Managers                  2.0        -54.0      0
# 4  5105705      F         Y              N               0  225000.0               Working  Secondary / secondary special         Married  Municipal apartment -12155               -667                   1                 0            0             0        Laborers                  2.0        -48.0      0

# %%
CreditCard.rename(columns={'Education level' : 'Education'}, inplace=True)

# %%
CreditCard.head()
# Out:
#         ID Gender Has a car Has a property  Children count    Income     Employment status                      Education  Marital status             Dwelling    Age  Employment length  Has a mobile phone  Has a work phone  Has a phone  Has an email       Job title  Family member count  Account age  class
# 0  5091261      F         N              Y               0  202500.0         State servant  Secondary / secondary special       Separated    House / apartment -16834              -1692                   1                 0            0             0  Medicine staff                  1.0         -6.0      0
# 1  5096963      M         Y              N               0  675000.0  Commercial associate               Higher education         Married    House / apartment -18126               -948                   1                 0            1             0        Managers                  2.0        -16.0      0
# 2  5087880      F         N              N               0  234000.0         State servant               Higher education  Civil marriage    House / apartment -21967              -5215                   1                 0            0             1      Core staff                  2.0        -52.0      0
# 3  5021949      F         Y              Y               0  445500.0  Commercial associate               Higher education         Married    House / apartment -12477               -456                   1                 0            0             0        Managers                  2.0        -54.0      0
# 4  5105705      F         Y              N               0  225000.0               Working  Secondary / secondary special         Married  Municipal apartment -12155               -667                   1                 0            0             0        Laborers                  2.0        -48.0      0

# %%
#print(CreditCard["Gender"].value_counts())
print(CreditCard["Education"].value_counts())
# Out:
# Education
# Secondary / secondary special    4974
# Higher education                 1954
# Incomplete higher                 281
# Lower secondary                    76
# Academic degree                     7
# Name: count, dtype: int64

# %%
mapeamento_replace = {
    "Secondary / secondary special" : "Graduado",    
    "Higher education" : "NaoGraduado",
    "Incomplete higher" : "NaoGraduado",               
    "Lower secondary" : "NaoGraduado",  
    "Academic degree" : "NaoGraduado"
}

CreditCard["Education"] = CreditCard["Education"].replace(mapeamento_replace)

# %%
print(CreditCard["Education"].value_counts())
# Out:
# Education
# Graduado       4974
# NaoGraduado    2318
# Name: count, dtype: int64

# %%
print(CreditCard["class"].value_counts())
print(CreditCard["class"].isnull().sum())
# Out:
# class
# 0    7175
# 1     117
# Name: count, dtype: int64
# 0

# %%
print(CreditCard.dtypes)
# Out:
# ID                       int64
# Gender                  object
# Has a car               object
# Has a property          object
# Children count           int64
# Income                 float64
# Employment status       object
# Education               object
# Marital status          object
# Dwelling                object
# Age                      int64
# Employment length        int64
# Has a mobile phone       int64
# Has a work phone         int64
# Has a phone              int64
# Has an email             int64
# Job title               object
# Family member count    float64
# Account age            float64
# class                    int64
# dtype: object

# %% [markdown]
# ## Codificando categorias

# %%
categorical_features = [i for i in CreditCard.columns if CreditCard.dtypes[i] in ['object', 'category']]
print(categorical_features)
# Out:
# ['Gender', 'Has a car', 'Has a property', 'Employment status', 'Education', 'Marital status', 'Dwelling', 'Job title']

# %%
categorical_names = {}
encoders = {}

for feature in categorical_features:
  le = LabelEncoder()
  le.fit(CreditCard[feature])

  CreditCard[feature] = le.transform(CreditCard[feature])

  categorical_names[feature] = le.classes_
  encoders[feature] = le

# %%
CreditCard = CreditCard.dropna()
CreditCard = CreditCard.astype(int)
# todos devem estar codificados em int64
CreditCard.dtypes
# Out:
# ID                     int64
# Gender                 int64
# Has a car              int64
# Has a property         int64
# Children count         int64
# Income                 int64
# Employment status      int64
# Education              int64
# Marital status         int64
# Dwelling               int64
# Age                    int64
# Employment length      int64
# Has a mobile phone     int64
# Has a work phone       int64
# Has a phone            int64
# Has an email           int64
# Job title              int64
# Family member count    int64
# Account age            int64
# class                  int64
# dtype: object

# %%
print(CreditCard.head())
# Out:
#         ID  Gender  Has a car  Has a property  Children count  Income  Employment status  Education  Marital status  Dwelling    Age  Employment length  Has a mobile phone  Has a work phone  Has a phone  Has an email  Job title  Family member count  Account age  class
# 0  5091261       0          0               1               0  202500                  2          0               2         1 -16834              -1692                   1                 0            0             0         11                    1           -6      1
# 1  5096963       1          1               0               0  675000                  0          1               1         1 -18126               -948                   1                 0            1             0         10                    2          -16      0
# 2  5087880       0          0               0               0  234000                  2          1               0         1 -21967              -5215                   1                 0            0             1          3                    2          -52      0
# 3  5021949       0          1               1               0  445500                  0          1               1         1 -12477               -456                   1                 0            0             0         10                    2          -54      0
# 4  5105705       0          1               0               0  225000                  4          0               1         2 -12155               -667                   1                 0            0             0          8                    2          -48      0

# %%
# Definições sobre os dados para avaliação de justiça
CreditCard.at[1, 'class'] = 0
CreditCard.at[0, 'class'] = 1
label_name ='class'
protected_attribute_names = ['Gender', 'Education']
favorable_classes = np.where(CreditCard['class'] == 0)[0]

# %%
# Definindo as populações privilegiadas e não-privilegiadas
# Gênero
## Recuperando o indice
privileged_sex   = np.where(categorical_names['Gender'] == 'M')[0]
unprivileged_sex = np.where(categorical_names['Gender'] == 'F')[0]
## Estabelecendo formato, seguindo o formato da documentacao das classes ClassificationMetric and BinaryLabelDatasetMetric
privileged_groups   = [{'Gender' : privileged_sex}]
unprivileged_groups = [{'Gender' : unprivileged_sex}]

#Escolaridade
## Recuperando o indice
privileged_faixa_etaria   = np.where(categorical_names['Education'] == 'Graduado')[0]
unprivileged_faixa_etaria = np.where(categorical_names['Education'] == 'NaoGraduado')[0]
## Estabelecendo formato, seguindo o formato da documentacao das classes ClassificationMetric and BinaryLabelDatasetMetric
privileged_groups_fe   = [{'Education' : privileged_faixa_etaria}]
unprivileged_groups_fe = [{'Education' : unprivileged_faixa_etaria}]


# Dados privilegiados
privileged_classes = [privileged_sex, privileged_faixa_etaria]

# %% [markdown]
# # Preparando experimentos

# %%
list_gbt_params = preparando_experimentos()
print(list_gbt_params)
# Out:
# Total de 600 conjuntos de parâmetros.
# Total de 240 conjuntos de parâmetros.
# [{'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.1, 'max_depth': 2, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.1, 'max_depth': 3, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.1, 'max_depth': 4, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.1, 'max_depth': 5, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.1, 'max_depth': 6, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.1, 'max_depth': 7, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.2, 'max_depth': 2, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.2, 'max_depth': 3, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.2, 'max_depth': 4, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.2, 'max_depth': 5, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.2, 'max_depth': 6, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.2, 'max_depth': 7, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.3, 'max_depth': 2, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.3, 'max_depth': 3, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.3, 'max_depth': 4, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.3, 'max_depth': 5, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.3, 'max_depth': 6, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.3, 'max_depth': 7, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.4, 'max_depth': 2, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.4, 'max_depth': 3, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.4, 'max_depth': 4, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.4, 'max_depth': 5, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.4, 'max_depth': 6, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.4, 'max_depth': 7, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.5, 'max_depth': 2, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.5, 'max_depth': 3, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.5, 'max_depth': 4, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.5, 'max_depth': 5, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.5, 'max_depth': 6, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.5, 'max_depth': 7, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 100, 'learning_rate': 0.1, 'max_depth': 2, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 100, 'learning_rate': 0.1, 'max_depth': 3, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 100, 'learning_rate': 0.1, 'max_depth': 4, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 100, 'learning_rate': 0.1, 'max_depth': 5, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 100, 'learning_rate': 0.1, 'max_depth': 6, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 100, 'learning_rate': 0.1, 'max_depth': 7, 'random_state': 2024}, {'n_estimators': 100, 'min_samples_split': 100, 'learning_rate': 0.2, 'max_depth': 2, 'random_state': 202 ...

# %% [markdown]
# # Toda a base

# %% [markdown]
# ## GBT

# %%
exp1_all_gbt = justica_exps(base, 'toda-a-base', CreditCard, list_gbt_params, 'gbt', categorical_features, 'class', favorable_classes, protected_attribute_names, privileged_classes, privileged_groups, unprivileged_groups, privileged_groups_fe, unprivileged_groups_fe)
# Out:
# <class 'dict'>
# {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.1, 'max_depth': 2, 'random_state': 2024}
# 0.98 de acuracia com desvio padrão de 0.00
# 0.51 de f1 com desvio padrão de 0.04
# /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 0.10 de precisão com desvio padrão de 0.20
# 0.98 de score no teste
# STATISTICAL PARITY DIFFERENCE
# Atributo sexo: 7.526719855487172e-06
# Atributo faixa_etaria: -0.00035622523275185983
#
# DISPARATE IMPACT
# Atributo sexo: 1.0027472527472527
# Atributo faixa_etaria: 0.8808426596445029
#
# AVERAGE ODDS DIFFERENCE
# Atributo sexo: -0.0548504354329597
# Atributo faixa_etaria: 0.057962590815897615
#
# EQUAL OPPORTUNITY DIFFERENCE
# Atributo sexo: -0.1111111111111111
# Atributo faixa_etaria: 0.11764705882352941
# {'index': 0, 'base': 'CreditCardApproval', 'attr_set': 'toda-a-base', 'modelo': 'gbt', 'param_set': "{'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.1, 'max_depth': 2, 'random_state': 2024}", '10fold-acuracia': 0.9811918191934307, '10fold-f1': 0.5143419545735946, '10fold-precisao': 0.1, 'test-score': 0.9849177330895795, 'spd_sexo': 7.526719855487172e-06, 'spd_faixa_etaria': -0.00035622523275185983, 'di_sexo': 1.0027472527472527, 'di_faixa_etaria': 0.8808426596445029, 'aod_sexo': -0.0548504354329597, 'aod_faixa_etaria': 0.057962590815897615, 'eod_sexo': -0.1111111111111111, 'eod_faixa_etaria': 0.11764705882352941}
#
# <class 'dict'>
# {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.1, 'max_depth': 3, 'random_state': 2024}
# 0.98 de acuracia com desvio padrão de 0.00
# 0.53 de f1 com desvio padrão de 0.06
# /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/tuao/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 0.11 de precisão com desvio padrão de 0.20
# 0.98 de score no teste
# STATISTICAL PARITY DIFFERENCE
# Atributo sexo: -0.004754112609735728
# Atributo faixa_etaria: -0.0014369403178829208
#
# DISPARATE IMPACT
# Atributo sexo: 0.22560787934749152
# Atributo faixa_etaria: 0.740273037542662
#
# AVERAGE ODDS DIFFERENCE
# Atributo sexo: -0.04520052841461757
# Atributo faixa_etaria: 0.04402760731874656
#
# EQUAL OPPORTUNITY DIFFERENCE
# Atributo sexo: -0.08695652173913043
# Atributo faixa_etaria: 0.09090909090909091
# {'index': 1, 'base': 'CreditCardApproval', 'attr_set': 'toda-a-base', 'modelo': 'gbt', 'param_set': "{'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.1, 'max_depth': 3, 'random_state': 2024}", '10fold-acuracia': 0.9800161160354552, '10fold-f1': 0.5279655950000237, '10fold-precisao': 0.10833333333333332, 'test-score': 0.9817184643510055, 'spd_sexo': -0.004754112609735728, 'spd_faixa_etaria': -0.0014369403178829208, 'di_sexo': 0.22560787934749152, 'di_faixa_etaria': 0.740273037542662, 'aod_sexo': -0.04520052841461757, 'aod_faixa_etaria': 0.04402760731874656, 'eod_sexo': -0.08695652173913043, 'eod_faixa_etaria': 0.09090909090909091}
#
# <class 'dict'>
# {'n_estimators': 100, 'min_samples_split': 50, 'learning_rate': 0.1, 'max_depth': 4, 'random_state': 2024}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 exp1_all_gbt = justica_exps(base, 'toda-a-base', CreditCard, list_gbt_params, 'gbt', categorical_features, 'class', favorable_classes, protected_attribute_names, privileged_classes, privileged_groups, unprivileged_groups, privileged_groups_fe, unprivileged_groups_fe)
#
# File ~/Google Drive/MateriaisDaFaculdade/IniciacaoCientifica/QuantificacaoDeViesEmAnaliseDeCredito/BibliotecasEFuncoes.py:106, in justica_exps(base, attr_set, df, parametros, modelo, categorical_features, label, fvr_classes, prt_attrs, priv_classes, unprivileged_groups, privileged_groups, unprivileged_groups_fe, privileged_groups_fe)
#     100 metric_pred_faixa_etaria = BinaryLabelDatasetMetric(dataset_pred,
#     101                                                     unprivileged_groups=unprivileged_groups_fe,
#     102                                                     privileged_groups=privileged_groups_fe)
#     104 # Submetendo modelo ao 10-fold cross validation (fitting)
#     105 # obtendo acurácia
# --> 106 scores1 = cross_val_score(clf, df2_train.features, df2_train.labels.ravel(), cv=10)
#     107 print("%0.2f de acuracia com desvio padrão de %0.2f" % (scores1.mean(), scores1.std()))
#     108 # obtendo f1_score
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:719, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, error_score)
#     716 # To ensure multimetric format is not supported
#     717 scorer = check_scoring(estimator, scoring=scoring)
# --> 719 cv_results = cross_validate(
#     720     estimator=estimator,
#     721     X=X,
#     722     y=y,
#     723     groups=groups,
#     724     scoring={"score": scorer},
#     725     cv=cv,
#     726     n_jobs=n_jobs,
#     727     verbose=verbose,
#     728     fit_params=fit_params,
#     729     params=params,
#     730     pre_dispatch=pre_dispatch,
#     731     error_score=error_score,
#     732 )
#     733 return cv_results["test_score"]
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:430, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     427 # We clone the estimator to make sure that all the folds are
#     428 # independent, and that it is pickle-able.
#     429 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 430 results = parallel(
#     431     delayed(_fit_and_score)(
#     432         clone(estimator),
#     433         X,
#     434         y,
#     435         scorer=scorers,
#     436         train=train,
#     437         test=test,
#     438         verbose=verbose,
#     439         parameters=None,
#     440         fit_params=routed_params.estimator.fit,
#     441         score_params=routed_params.scorer.score,
#     442         return_train_score=return_train_score,
#     443         return_times=True,
#     444         return_estimator=return_estimator,
#     445         error_score=error_score,
#     446     )
#     447     for train, test in indices
#     448 )
#     450 _warn_or_raise_about_fit_failures(results, error_score)
#     452 # For callable scoring, the return type is only know after calling. If the
#     453 # return type is a dictionary, the error scores can now be inserted with
#     454 # the correct key.
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/utils/parallel.py:129, in _FuncWrapper.__call__(self, *args, **kwargs)
#     127     config = {}
#     128 with config_context(**config):
# --> 129     return self.function(*args, **kwargs)
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:895, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     893         estimator.fit(X_train, **fit_params)
#     894     else:
# --> 895         estimator.fit(X_train, y_train, **fit_params)
#     897 except Exception:
#     898     # Note fit time as time until error
#     899     fit_time = time.time() - start_time
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/ensemble/_gb.py:784, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     781     self._resize_state()
#     783 # fit the boosting stages
# --> 784 n_stages = self._fit_stages(
#     785     X_train,
#     786     y_train,
#     787     raw_predictions,
#     788     sample_weight_train,
#     789     self._rng,
#     790     X_val,
#     791     y_val,
#     792     sample_weight_val,
#     793     begin_at_stage,
#     794     monitor,
#     795 )
#     797 # change shape of arrays after fit (early-stopping or additional ests)
#     798 if n_stages != self.estimators_.shape[0]:
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/ensemble/_gb.py:880, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     873         initial_loss = factor * self._loss(
#     874             y_true=y_oob_masked,
#     875             raw_prediction=raw_predictions[~sample_mask],
#     876             sample_weight=sample_weight_oob_masked,
#     877         )
#     879 # fit next stage of trees
# --> 880 raw_predictions = self._fit_stage(
#     881     i,
#     882     X,
#     883     y,
#     884     raw_predictions,
#     885     sample_weight,
#     886     sample_mask,
#     887     random_state,
#     888     X_csc=X_csc,
#     889     X_csr=X_csr,
#     890 )
#     892 # track loss
#     893 if do_oob:
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/ensemble/_gb.py:490, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     487     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     489 X = X_csc if X_csc is not None else X
# --> 490 tree.fit(
#     491     X, neg_g_view[:, k], sample_weight=sample_weight, check_input=False
#     492 )
#     494 # update tree leaves
#     495 X_for_tree_update = X_csr if X_csr is not None else X
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/tree/_classes.py:1377, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1347 @_fit_context(prefer_skip_nested_validation=True)
#    1348 def fit(self, X, y, sample_weight=None, check_input=True):
#    1349     """Build a decision tree regressor from the training set (X, y).
#    1350
#    1351     Parameters
#    (...)
#    1374         Fitted estimator.
#    1375     """
# -> 1377     super()._fit(
#    1378         X,
#    1379         y,
#    1380         sample_weight=sample_weight,
#    1381         check_input=check_input,
#    1382     )
#    1383     return self
#
# File ~/anaconda3/envs/aif360/lib/python3.11/site-packages/sklearn/tree/_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %% [markdown]
# ## RF

# %%
exp2_all_rf = justica_exps(base, 'toda-a-base', taiwan, list_rf_params, 'rf', categorical_features, 'class', favorable_classes, protected_attribute_names, privileged_classes)
